# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani221/CSproject/blob/main/pre_requirements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting image from web using wbget
# !wget 'https://thumbs.dreamstime.com/b/golden-retriever-dog-21668976.jpg'
# Out:
# --2022-08-14 17:51:30--  https://thumbs.dreamstime.com/b/golden-retriever-dog-21668976.jpg
# Resolving thumbs.dreamstime.com (thumbs.dreamstime.com)... 192.229.163.122
# Connecting to thumbs.dreamstime.com (thumbs.dreamstime.com)|192.229.163.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101996 (100K) [image/jpeg]
# Saving to: ‘golden-retriever-dog-21668976.jpg’
#
# golden-retriever-do 100%[===================>]  99.61K  --.-KB/s    in 0.02s
#
# 2022-08-14 17:51:30 (4.67 MB/s) - ‘golden-retriever-dog-21668976.jpg’ saved [101996/101996]

# %% [markdown]
# *   matplotlib.image
#
#
#
#
#
#
#
# *   pillow
# *   open cv(cv2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread("/content/doggo.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
#rgb 3 color channel , greyscale 1 colour channel
#first 2 values represent dimensiosn , width*height
#0 is black , 255 is whit and rgb has 3 matrices representing each
#total pixel is 533*800
# Out:
# (533, 800, 3)

# %%
print(img)
# Out:
# [[[132 146 146]
#   [133 148 145]
#   [135 150 147]
#   ...
#   [ 13  17   2]
#   [ 13  17   2]
#   [ 13  17   2]]
#
#  [[132 146 146]
#   [133 148 145]
#   [135 150 147]
#   ...
#   [ 13  17   2]
#   [ 13  17   2]
#   [ 13  17   2]]
#
#  [[132 146 146]
#   [133 148 145]
#   [135 150 147]
#   ...
#   [ 13  17   3]
#   [ 13  17   3]
#   [ 12  16   2]]
#
#  ...
#
#  [[116  28  68]
#   [116  17  64]
#   [108   0  50]
#   ...
#   [ 14  15   7]
#   [ 26  30  16]
#   [  6  10   0]]
#
#  [[164  92 116]
#   [155  63 104]
#   [133  19  81]
#   ...
#   [ 10  12   0]
#   [  6  11   0]
#   [  0   6   0]]
#
#  [[187 129 144]
#   [176  91 130]
#   [151  36 103]
#   ...
#   [  6   3  22]
#   [  0   0   9]
#   [ 12  13  15]]]

# %%
#display image from numpy
img_plot=plt.imshow(img)
plt.show()

# %%
#resize image using pillow
from PIL import Image

# %%
img=Image.open("/content/doggo.jpg")
img_resized = img.resize((200,200))
img_resized.save("dog_resize.jpg")

# %%
#display image from numpy
img_plot=plt.imshow(img_resized)
plt.show()

# %%
img_resized=mpimg.imread("/content/dog_resize.jpg")
print(img_resized.shape)
print(img_resized)
# Out:
# (200, 200, 3)
# [[[140 145 151]
#   [142 147 151]
#   [135 141 139]
#   ...
#   [  9  12   1]
#   [ 10  13   2]
#   [ 11  14   3]]
#
#  [[135 143 146]
#   [139 144 147]
#   [133 139 137]
#   ...
#   [  8  11   2]
#   [  9  12   3]
#   [  9  12   3]]
#
#  [[130 138 140]
#   [132 141 140]
#   [129 135 131]
#   ...
#   [  5   8   0]
#   [  6   9   0]
#   [  7  10   1]]
#
#  ...
#
#  [[ 77  18  64]
#   [ 94  16  66]
#   [113  15  66]
#   ...
#   [ 53  43  33]
#   [ 33  26  16]
#   [ 20  20  10]]
#
#  [[ 75   2  55]
#   [ 84   0  55]
#   [108   0  59]
#   ...
#   [ 46  38  27]
#   [ 49  47  35]
#   [ 27  29  18]]
#
#  [[129  46 102]
#   [ 94   0  58]
#   [110   0  60]
#   ...
#   [ 13   7   0]
#   [ 43  41  29]
#   [  4   7   0]]]

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img=cv2.imread("/content/doggo.jpg")

# %%
type(img)
img.shape
# Out:
# (533, 800, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (533, 800)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=800x533 at 0x7F0FF7A0C950>

# %%
# saving the grayscale image
cv2.imwrite('dog_grayscale_image.jpg', grayscale_image)
# Out:
# True
